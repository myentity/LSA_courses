# %%
import pandas as pd
from pandas import read_csv, DataFrame

# %%
st=''
s = pd.read_excel('../answ_1_1.xlsx')
print(s.describe())
# Out:
#               id
# count  48.000000
# mean   36.750000
# std    22.464629
# min     1.000000
# 25%    17.750000
# 50%    38.500000
# 75%    57.500000
# max    72.000000

# %%
text = []
for i, row in s.iterrows():
    if (isinstance(row['answer'], str)):
        st = row['answer']
    else:
        st = str(row['answer'])
    text.append(st)
print(len(text))
# Out:
# 48

# %%
ignorechars = '''(){},."":;-*<>'?\!'''
stopwords = ['n','тк','чтоб','какуюлиб','точт','мне','да','нет','всех','5','я','кем','ч','м','др','2014','4','6','8','3',
             '2','1','тут','тех','нас','нам','тог','когд','такж','межд','е','ты','теб','чьи','чег','всем','всю','тож','им',
             'над','себ','либ','инач','без','их','вам','чем','есл','ещ','ег','изз','тем','там','уж','вместе','сам','уже',
             'ей','тд','где','как','он','мы','так','в','на','о','об','не','но','по','а','и','все','это','при','с','S','было',
             'быть','был','много','однако','те','нами','теми','то','есть','ему','его','сих','пор','же','во','под','если',
             'ли','у','.','та','со','за','ту','них','к','для','того','чтобы','бы','из','до','или','ни','эт','котор','что',
             'ил', 'эссе']
exec(open('../LSI.py', encoding="utf8").read())

# %%
lsa = LSI(stopwords, ignorechars, text)
lsa.build()

# %%
lsa.calc()

# %%
lsa.print_svd()

# %%
df = pd.DataFrame(-1*lsa.U[:,1:3])
print (lsa.fulldictionary[i])
df[:5]
# Out:
# содержанием
#           0         1
# 0  0.004563 -0.007115
# 1  0.018350 -0.041760
# 2  0.024185  0.012326
# 3 -0.011501 -0.180435
# 4  0.085015 -0.134359

# %%
df = pd.DataFrame(-1*lsa.U[:,1:3])
#попробовать взять 0:2
df = df.rename(columns={0:'x', 1:'y'})
df.insert(2,'dots', [lsa.fulldictionary[i] for i in lsa.keys])
df[:5]
# Out:
#           x         y             dots
# 0  0.004563 -0.007115             эссе
# 1  0.018350 -0.041760     модернизация
# 2  0.024185  0.012326          системы
# 3 -0.011501 -0.180435  педагогического
# 4  0.085015 -0.134359      образования

# %%
doc_coord = pd.DataFrame(-1*lsa.Vt[1:3, :])
doc_coord = doc_coord.transpose()
doc_coord = doc_coord.rename(columns={0:'x', 1:'y'})
#doc_coord.insert(2,'dots', [i for i in numpy.arange(1,len(text)+1)])
est = []
est1 = []
est2 = []
est3 = []
alpha = []
for i,row in s.iterrows():
    est.append(row['id'])
    est1.append(row['fio'])
doc_coord.insert(2,'id', est)
doc_coord.insert(3,'fio', est1)
print(doc_coord)
# Out:
#            x         y  id                               fio
# 0   0.066514 -0.183666   1            Алиева Сацита Адамовна
# 1   0.019972 -0.043371   2    Андраник Грантович Сулейманян
# 2   0.008865 -0.001652   3        Андрианов Юрий Васильевич
# 3  -0.007669  0.212767   4        Анисимова Татьяна Ивановна
# 4   0.059128 -0.096571   5         Анна Витальевна Невзорова
# 5  -0.074927  0.513734   6              Анна Федоровна Шмидт
# 6   0.078305 -0.104160   7        Асафова Елена Владимировна
# 7   0.053462 -0.252769   9        Белозерова Лилия Алмазовна
# 8   0.095140 -0.210910  13         Бывшева Марина Валерьевна
# 9   0.003932  0.097545  14       Важнова Светлана Алексеевна
# 10  0.126255  0.055321  16      Васильева Надежда Николаевна
# 11  0.059521  0.069792  17        Васягина Наталия Николевна
# 12  0.008855  0.288851  18      Вахрушева Людмила Николаевна
# 13  0.007767  0.034639  19     Воронина Людмила Валентиновна
# 14  0.006024  0.085498  21       Галямова Эльмира Махмудовна
# 15  0.051440 -0.013420  22       Ганиева Гульчачак Рафисовна
# 16 -0.461903 -0.031392  23        Глухова Галина Анатольевна
# 17 -0.002525 -0.008681  24           Гришина Ольга Сергеевна
# 18  0.115036 -0.007168  27     Дмитриева Людмила Геннадьевна
# 19 -0.078136  0.098672  29       Жукова Наталья Вячеславовна
# 20  0.017364  0.043540  30        Зайцев Сергей Викторович
# 21  0.029968  0.120510  32          Зверева Ольга Леонидовна
# 22  0.027104 -0.034897  37         Коротких Ольга Валерьевна
# 23 -0.147536 -0.089522  38        Котов Сергей Владимирович
# 24  0.010874 -0.083986  39    Леонтьева Наталия Владимировна
# 25  0.282602  0.111088  40        Лисина Валерия Рудольфовна
# 26 -0.010584 -0.006328  41      Литвина Анастасия Леонидовна
# 27 -0.033558  0.109348  42          Лыткина Аксана Виликовна
# 28  0.088131 -0.066027  43        Медведева Ирина Николаевна
# 29  0.194670 -0.119046  44  Меркулова Татьяна Константиновна
# 30  0.068829 -0.109671  45      Мешкова Наталья Владимировна
# 31  0.031913  0.116502  49       Неясова Ирина Александровна
# 32 -0.003931 -0.007020  50      Никандрова Татьяна Сергеевна
# 33  0.091860  0.112513  55           Пестерева Елена Юрьевна
# 34  0.120898  0.074897  56            Петрова Дина Борисовна
# 35  0.055015 -0.096443  57        Поздеева Оксана Георгиевна
# 36  0.113173 -0.226087  59           Рашкован Ефим Абрамович
# 37  0.027766 -0.053441  60        Рожина Светлана Валерьевна
# 38 -0.004819 -0.058527  61     Сабурова Александра Андреевна
# 39  0.170090 -0.304854  62        Сахиева Регина Геннадьевна
# 40  0.002074  0.117866  63       Силакова Марина Михайловна
# 41  0.478909  0.157397  65  Содномдоржиева Эржена Аркадьевна
# 42 -0.002598  0.082037  66          Соловьева Ирина Олеговна
# 43 -0.461903 -0.031392  68         Стрелкова Ольга Борисовна
# 44  0.026425  0.034318  69       Фатыхов Миннехан Абузарович
# 45 -0.209120 -0.208183  70        Фролова Наталья Викторовна
# 46  0.027381 -0.001415  71        Хузеева Гузелия Рифкатовна
# 47  0.000203  0.190244  72            Черная Анна Викторовна

# %%
source = ColumnDataSource(data=dict(x=df.x, y=df.y, dots=df.dots))
source2 = ColumnDataSource(data=dict(x=doc_coord.x, y=doc_coord.y, estimate=doc_coord.id, estimate1=doc_coord.fio))

hover = HoverTool(tooltips=[
    ("x","@x"),
    ("y", "@y"),
    ("fio", "@estimate"),
    ("id", "@estimate1")
])

TOOLS = "pan, wheel_zoom, box_zoom, reset, save, box_select, crosshair"

output_notebook()
p = figure(plot_height=600, plot_width=800, title="Расположение слов на плоскости", tools=[hover, TOOLS])
p.circle(df.x, df.y, source=source, size=10, line_color="navy", fill_color="orange", fill_alpha=0.5)
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="80f7115e-df0d-4e45-8597-eecc5546eb8e">Loading BokehJS ...</span>
#     </div>
# /Users/anastasiapanfilova/py3_kernel/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
# /Users/anastasiapanfilova/py3_kernel/lib/python3.5/site-packages/bokeh/util/deprecation.py:34: BokehDeprecationWarning:
# Supplying a user-defined data source AND iterable values to glyph methods is deprecated.
#
# See https://github.com/bokeh/bokeh/issues/2056 for more information.
#
#   warn(message)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9ff57a79-83b2-4eff-9ba5-d1bfeb007efc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("9ff57a79-83b2-4eff-9ba5-d1bfeb007efc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9ff57a79-83b2-4eff-9ba5-d1bfeb007efc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9ff57a79-83b2-4eff-9ba5-d1bfeb007efc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d8eb7e8f-3f5d-4f1e-8281-8da9e87fe5a4":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ca7c38e1-3b1a-43e7-b4d0-829f442a9be7","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"3155337c-aef2-44b3-9120-41775801e83f","type":"BasicTickFormatter"},"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"456cd426-05c9-4640-9911-45b9e2358aa7","type":"BasicTicker"}},"id":"bb1e76ff-02da-40ef-b4fb-d4110a6e9a7c","type":"LinearAxis"},{"attributes":{"formatter":{"id":"d1761bcd-ed09-45a0-b6b0-baaed8dabfdd","type":"BasicTickFormatter"},"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"95915251-4190-4406-9f86-778953695bee","type":"BasicTicker"}},"id":"322bdb2a-3a10-44ab-894d-dd08a0e6ca70","type":"LinearAxis"},{"attributes":{"plot":null,"text":"\u0420\u0430\u0441\u043f\u043e\u043b\u043e\u0436\u0435\u043d\u0438\u0435 \u0441\u043b\u043e\u0432 \u043d\u0430 \u043f\u043b\u043e\u0441\u043a\u043e\u0441\u0442\u0438"},"id":"ff20f9be-4cdf-46e5-be51-b64ca7b16353","type":"Title"},{"attributes":{"data_source":{"id":"53eed7f0-f515-421b-98c8-43bf8f23963e","type":"ColumnDataSource"},"glyph":{"id":"f672cfa5-b999-4fc4-9b40-1eda7bd07a1d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"4df51a79-aa61-44f2-a130-2a2b8a6936cb","type":"Circle"},"selection_glyph":null},"id":"00574b97-446c-4cc3-b031-2b9a0d4b9d11","type":"GlyphRenderer"},{"attributes":{},"id":"3155337c-aef2-44b3-9120-41775801e83f","type":"BasicTickFormatter"},{"attributes":{"dimension":1,"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"},"ticker":{"id":"456cd426-05c9-4640-9911-45b9e2358aa7","type":"BasicTicker"}},"id":"3bc476b8-1e92-44c3-aec6-520e412b59e6","type":"Grid"},{"attributes":{"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"}},"id":"bdb8d126-fd83-4d57-b9b8-5c4eddc2705f","type":"CrosshairTool"},{"attributes":{},"id":"d1761bcd-ed09-45a0-b6b0-baaed8dabfdd","type":"BasicTickFormatter"},{"attributes":{},"id":"b8e2adc3-256d-41be-843e-2b1916cbd9a0","type":"ToolEvents"},{"attributes":{"callback":null,"overlay":{"id":"ca7c38e1-3b1a-43e7-b4d0-829f442a9be7","type":"BoxAnnotation"},"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"},"renderers":[{"id":"00574b97-446c-4cc3-b031-2b9a0d4b9d11","type":"GlyphRenderer"}]},"id":"062c1f83-b75b-421f-b8ca-83e305b4a638","type":"BoxSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bef3604c-f111-4e93-b0bd-2135625ec18a","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"orange"},"line_color":{"value":"navy"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"f672cfa5-b999-4fc4-9b40-1eda7bd07a1d","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"4df51a79-aa61-44f2-a130-2a2b8a6936cb","type":"Circle"},{"attributes":{"callback":null,"plot":{"id":"87981ac3-e2c4-4df7-b7ab-98b9e0a983b1","subtype":"Figure","type":"Plot"},"tooltips":[["x","@x"],["y","@y"],["fio","@estimate"],["id","@estimate1"]]},"id":"e84d0a24-f291-4849-94eb-b5b48051fa00","type":"HoverTool"},{"attributes":{"callback":null,"column_names":["y", ...
